# %%
import pandas as pd
import numpy as np # numerical
import matplotlib.pyplot as plt # drawing
import seaborn as sns #drawing

# %%
data ={
    'area':[2600, 3000, 3200, 3600, 4000],
    'price':[5550000, 5655000, 6100000, 6800000, 7250000]
}
data
df=pd.DataFrame(data)
df
# Out:
#    area    price
# 0  2600  5550000
# 1  3000  5655000
# 2  3200  6100000
# 3  3600  6800000
# 4  4000  7250000

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df['area'],df['price'] ,color='red',marker='*')

# %%
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='blue',marker='.')

# %%
area= df[['area']]# 2d (features always 2D)
area
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price=df["price"]# 1D (target always 1D)
price
# Out:
# 0    5550000
# 1    5655000
# 2    6100000
# 3    6800000
# 4    7250000
# Name: price, dtype: int64

# %% [markdown]
# Skicit Learn

# %%
# !pip install -U scikit-learn # وهي library مسئولة اني اجيب منها model وهي library بتقدر انها تعملي predict
#مبينه ب c++علشان تبقي سريعه
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 61.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ...

# %%
from sklearn.linear_model import LinearRegression
#linear_model#---->هو عبارة عن module جوه sklearn
#linear_model----->في منه انوا كتير منها regression
#ِalgorithms
#Ridge
#Lasso
#LogisticRegression
# SGDRegressor

# %%
model= LinearRegression()

# %%
df.shape
#5 rows (اللي فيهم اسعار البيوت والمساحة), 2 colums(area,price)
# Out:
# (5, 2)

# %%
model.fit(area,price)# training---> features and target
# Out:
# LinearRegression()

# %% [markdown]
# result-->c(slope)

# %%
#m (slope)=135قيمة احسن ميل قدر ال model انه يوصله
model.coef_
# Out:
# array([1327.56849315])

# %% [markdown]
# c-->constant
#
# y(targetسعر الشقة)=1327.5x(inputمساحة الشقة )+1916575.3

# %%
model.intercept_ # c
# Out:
# np.float64(1916575.3424657527)

# %%
model.predict([[200]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2182089.04109589])

# %%
plt.xlabel("area")
plt.ylabel("price")
#عاوز ارسم النقاط وكمان ارسم احسن slope
#scatter بيقدر انه يرسملي الداتا في شكل point
plt.scatter(df['area'],df['price'],color="blue",marker='.')
#plot هترسملي الداتا في شكل خط مستقيم وهوو شكل slpe
#المفروض اني بدخلها ال features في المعادلة وتطلعلي ال output
plt.plot(df['area'],model.predict(area))#y=model.predict(area) دي قيمة y الجديدة اللي الموديل هيتنبأ بيها

# %%
data={
    'year' :[1970, 1971, 1972, 1973, 1974],
    'per capita income (US$)':[3399.299037,
        3768.297935,
        4251.175484,
        4804.463248,
        5576.514583]
}
df1=pd.DataFrame(data)
df1
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
model1=LinearRegression()

# %%
x=df1[['year']]
x.shape
# Out:
# (5, 1)

# %%
y=df1['per capita income (US$)']
y.shape
# Out:
# (5,)

# %%
model1.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# slope=539.0596405

# %%
model1.coef_
# Out:
# array([539.0596405])

# %% [markdown]
# y=539.0596405x+-1058665.6610
# c=-1058665.6610

# %%
model1.intercept_
# Out:
# np.float64(-1058665.6610086)

# %%
model1.predict([[2001]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19992.6796319])

# %%
model1.predict([[3000]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([558513.2604914])

# %%
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df1['year'],df1['per capita income (US$)'],color='red',marker='+')

plt.plot(df1['year'],model1.predict(x))

# %%
dd={
    'area' :[1500, 1800, 2000, 2200, 2500, 2800, 3000, 3200, 3500, 4000],
    'bedrooms':[2, 3, 3, 3, 4, 4, 4, 5, 5, 5],
    'price': [3200000, 4100000, 4800000, 5200000, 6200000,
              7100000, 7800000, 8500000, 9500000, 11000000]


}
df2=pd.DataFrame(dd)
df2
# Out:
#    area  bedrooms     price
# 0  1500         2   3200000
# 1  1800         3   4100000
# 2  2000         3   4800000
# 3  2200         3   5200000
# 4  2500         4   6200000
# 5  2800         4   7100000
# 6  3000         4   7800000
# 7  3200         5   8500000
# 8  3500         5   9500000
# 9  4000         5  11000000

# %%
model3=LinearRegression()

# %%
feature=df2[['area','bedrooms']]
feature.shape
# Out:
# (10, 2)

# %%
target=df2['price']
target.shape
# Out:
# (10,)

# %%
model3.fit(feature,target)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([1327.56849315])

# %%
model.intercept_
# Out:
# np.float64(1916575.3424657527)

# %%
model3.predict([[1500,2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3125950.50215208])

# %%
# over fitting
plt.figure(figsize=(12, 5))


# رسم Area vs Price
plt.subplot(1, 2, 1)
plt.scatter(df2['area'], df2['price'], color='red')
plt.xlabel('Area (sq ft)')
plt.ylabel('Price')
plt.title('Area vs Price')
plt.plot(df2['area'],model3.predict(feature))

# رسم Bedrooms vs Price
plt.subplot(1, 2, 2)
plt.scatter(df2['bedrooms'], df2['price'], color='blue')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.title('Bedrooms vs Price')
plt.plot(df2['bedrooms'],model3.predict(feature))
plt.show()
